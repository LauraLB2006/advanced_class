# %%
import requests
import pandas as pd
import json

# %%
df1 = pd.read_csv("fsi-2018.CSV")
df1.head()
# Out:
#                     Country    Year Rank  Total  C1: Security Apparatus  \
# 0               South Sudan  2018.0  1st  113.4                    10.0
# 1                   Somalia  2018.0  2nd  113.2                     9.7
# 2                     Yemen  2018.0  3rd  112.7                     9.9
# 3                     Syria  2018.0  4th  111.4                     9.9
# 4  Central African Republic  2018.0  5th  111.1                     9.1
#
#    C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 0                       9.7                  9.7         10.0
# 1                      10.0                  9.0          8.9
# 2                      10.0                  9.5          9.6
# 3                       9.9                  9.9          8.5
# 4                       9.7                  8.8          8.8
#
#    E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                      8.9                               6.3
# ...

# %%
df1.columns.values
# Out:
# array(['Country', 'Year', 'Rank', 'Total', 'C1: Security Apparatus',
#        'C2: Factionalized Elites', 'C3: Group Grievance', 'E1: Economy',
#        'E2: Economic Inequality', 'E3: Human Flight and Brain Drain',
#        'P1: State Legitimacy', 'P2: Public Services', 'P3: Human Rights',
#        'S1: Demographic Pressures', 'S2: Refugees and IDPs',
#        'X1: External Intervention'], dtype=object)

# %%
c1 = df1.sort_values (by= "C1: Security Apparatus")

# %%
c1 [:10]
# Out:
#          Country    Year   Rank  Total  C1: Security Apparatus  \
# 173      Iceland  2018.0  174th   20.3                     0.8
# 163     Portugal  2018.0  164th   27.3                     1.0
# 164      Austria  2018.0  165th   26.2                     1.3
# 160    Singapore  2018.0  161st   30.4                     1.3
# 161     Slovenia  2018.0  162nd   30.3                     1.3
# 175  Switzerland  2018.0  176th   19.2                     1.4
# 174      Denmark  2018.0  175th   19.8                     1.4
# 171   Luxembourg  2018.0  170th   20.8                     1.4
# 168  New Zealand  2018.0  169th   20.9                     1.5
# 176       Norway  2018.0  177th   18.3                     1.8
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.8                  1.1          3.2
# 163                       2.5                  2.2          4.8
# 164                       3.2                  4.8          1.9
# ...

# %%
df1_dict = {'C1': 'C1: Security Apparatus',
              'C2': 'C2: Factionalized Elites',
              'C3': 'C3: Group Grievance',
              'E1': 'E1: Economy',
              'E2': 'E2: Economic Inequality',
              'E3': 'E3: Human Flight and Brain Drain',
              'P1': 'P1: State Legitimacy',
              'P2': 'P2: Public Services',
              'P3': 'P3: Human Rights',
              'S1': 'S1: Demographic Pressures',
              'S2': 'S2: Refugees and IDPs',
              'X1': 'X1: External Intervention'}

for d in df1_dict:
    #df1_sort = df1.sort_values (by= "C1", "C2", "C3", "E1", "E2", "E3", "P1", "P2", "P3", "S1", "S2", "X1")  
    #df1.sort_values (by= "d")
    #df1.array ([4:15])
    #print (df1_dict.columns.values)
    #print (d [:10])
    df1_dict

# %%
c1 = df1.sort_values (by= "C1: Security Apparatus")
c2 = df1.sort_values (by= 'C2: Factionalized Elites')
c3 = df1.sort_values (by= 'C3: Group Grievance')
e1 = df1.sort_values (by= 'E1: Economy')
e2 = df1.sort_values (by= 'E2: Economic Inequality')
e3 = df1.sort_values (by= 'E3: Human Flight and Brain Drain')
p1 = df1.sort_values (by= 'P1: State Legitimacy')
p2 = df1.sort_values (by= 'P2: Public Services')
p3 = df1.sort_values (by= 'P3: Human Rights')
s1 = df1.sort_values (by= 'S1: Demographic Pressures')
s2 = df1.sort_values (by= 'S2: Refugees and IDPs')
x1 = df1.sort_values (by= 'X1: External Intervention')

# %%
print (c1 [:10], c2 [:10], c3[:10], e1 [:10], e2 [:10], e3 [:10], p1 [:10], p2 [:10], s1 [:10], s2 [:10], x1 [:10])
# Out:
#          Country    Year   Rank  Total  C1: Security Apparatus  \
# 173      Iceland  2018.0  174th   20.3                     0.8
# 163     Portugal  2018.0  164th   27.3                     1.0
# 164      Austria  2018.0  165th   26.2                     1.3
# 160    Singapore  2018.0  161st   30.4                     1.3
# 161     Slovenia  2018.0  162nd   30.3                     1.3
# 175  Switzerland  2018.0  176th   19.2                     1.4
# 174      Denmark  2018.0  175th   19.8                     1.4
# 171   Luxembourg  2018.0  170th   20.8                     1.4
# 168  New Zealand  2018.0  169th   20.9                     1.5
# 176       Norway  2018.0  177th   18.3                     1.8
#
#      C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 173                       1.8                  1.1          3.2
# 163                       2.5                  2.2          4.8
# 164                       3.2                  4.8          1.9
# ...

# %%
df1_dict
# Out:
# {'C1': 'C1: Security Apparatus',
#  'C2': 'C2: Factionalized Elites',
#  'C3': 'C3: Group Grievance',
#  'E1': 'E1: Economy',
#  'E2': 'E2: Economic Inequality',
#  'E3': 'E3: Human Flight and Brain Drain',
#  'P1': 'P1: State Legitimacy',
#  'P2': 'P2: Public Services',
#  'P3': 'P3: Human Rights',
#  'S1': 'S1: Demographic Pressures',
#  'S2': 'S2: Refugees and IDPs',
#  'X1': 'X1: External Intervention'}
